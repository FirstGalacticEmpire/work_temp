# %%
import lxml

# %%
import xml.sax
class WikiXmlHandler(xml.sax.handler.ContentHandler):
    """Content handler for Wiki XML data using SAX"""
    def __init__(self):
        xml.sax.handler.ContentHandler.__init__(self)
        self._buffer = None
        self._values = {}
        self._current_tag = None
        self._pages = []

    def characters(self, content):
        """Characters between opening and closing tags"""
        if self._current_tag:
            self._buffer.append(content)

    def startElement(self, name, attrs):
        """Opening tag of element"""
        if name in ('title', 'text'):
            self._current_tag = name
            self._buffer = []

    def endElement(self, name):
        """Closing tag of element"""
        if name == self._current_tag:
            self._values[name] = ' '.join(self._buffer)

        if name == 'page':
            self._pages.append((self._values['title'], self._values['text']))

# %%
data_path = './wiki_data/plwiki-20220520-pages-meta-current6.xml-p4962394p5290879.bz2'

# %%
import subprocess

# %%
# Object for handling xml
handler = WikiXmlHandler()# Parsing object
parser = xml.sax.make_parser()
parser.setContentHandler(handler)# Iteratively process file
for line in subprocess.Popen(['bzcat'], stdin = open(data_path), stdout = subprocess.PIPE).stdout:
    parser.feed(line)
    
    # Stop when 3 articles have been found
    if len(handler._pages) > 2:
        break

# %%
handler._pages[0]
# Out:
# ('Grób Cyrusa II Wielkiego',
#  '{{Budynek infobox \n  |nazwa                 = Mauzoleum Cyrusa Wielkiego \n  |nazwa oryginalna      = آرامگاه کوروش بزرگ (po persku) \n  |zabytek               = [[Lista światowego dziedzictwa UNESCO]] o [http://whc.unesco.org/en/list/1106 ID 1106], jako część Pasargady < br / > W Iranie zabytek o ID 19. \n  |zdjęcie               = Tomb of Cyrus the Great (cropped 4-3).jpg \n  |opis zdjęcia          = Grobowiec Cyrusa II Wielkiego \n  |alt zdjęcia           =  \n  |państwo               = Iran \n  |miejscowość           = [[Pasargady]] \n  |adres                 =  \n  |typ budynku           = [[Mauzoleum]] \n  |styl architektoniczny = [[Architektura Achemenidzka]], [[Architektura Staroperska]] \n  |architekt             =  \n  |inwestor              =  \n  |wysokość całkowita    =  \n  |wysokość do dachu     =  \n  |kondygnacje           =  \n  |powierzchnia użytkowa =  \n  |rozpoczęcie budowy    = ok. 550 r.p.n.e. \n  |ukończenie budowy     = 529 r. p.n.e. \n  |przebudowy            =  \n  |zniszczono            =  \n  |odbudowano            =  \n  |pierwszy właściciel   = Cyrus, Król, Achemenida \n  |kolejni właściciele   =  \n  |właściciel            =  \n  |plan budynku          = CyrustheGreatTombDrawingbyThruthSeeker 22042.png \n  |współrzędne           = 30° 11′ 38″ N, 53° 10′ 2″ E \n  |commons               = Category:Tomb of Cyrus the Great \n  |www                   = http://whc.unesco.org/en/list/1106 \n }} \n \'\'\'Grobowiec Cyrusa, mauzoleum Cyrusa\'\'\' ([[Język perski|perski]]: آرامگاه کوروش بزرگ [[Transliteracja|trl.]] ārāmgāh-e kurosh-e bozorg) – grobowiec wzniesiony w VI w. p.n.e. dla władcy Persji [[Cyrus II Wielki|Cyrusa II Wielkiego]]. Znajduje się około 1 km na południowy zachód od pałacu w [[Pasargady|Pasargadach]] w [[Iran]]ie{{odn|Stronach|1978| s=9-10}}. \n \n Według źródeł greckich datowany na lata między zwycięstwem nad [[Astyages]]em < ref > {{Cytuj |autor = [[Strabon]] |tytuł =  " The Geography of Strabo. Literally translated, with notes, in three volumes "  |data = 1889 |inni = W. Falconer;H. C. Hamilton (tłum.) |miejsce = London |wydawca = George Bell  &  Sons |wolumin =3 |s =Strb. XV.3.8, s.134 |url = https://books.google.pl/books?id=rucyAAAAYAAJ & hl=pl & pg=PA134#v=onepage & q & f=false | data dostępu = 2020-12-18|język = en}} < /ref > {{odn|Briant|2002| s=85}}{{odn|Nawotka|2004| s=349}}  \n (550 p.n.e.), a początkiem panowania [[Kambyzes II|Kambizesa]] (529 p.n.e.). Według badań archeologicznych został wybudowany, tak jak całe [[Pasargady]], po zdobyciu [[Sardes]] w latach 546-530 p.n.e.{{odn|Briant|2002| s=85}}{{odn|Stronach|1978| s=42, 22-23}} \n \n Najobszerniejszy starożytny opis wyglądu i historii mauzoleum Cyrusa pochodził z zaginionej relacji {{link-interwiki | Arystobul Kasandryjski| lang=en | tam=Aristobulus of Cassandreia| tekst=Arystobula}}, który, na rozkaz [[Aleksander Macedoński|Aleksandra Macedońskiego]] kierował najpierw jego ozdabianiem, a potem naprawą. Na jego relacji opierają się przekazy [[Strabon]]a (przytacza dodatkowo bardzo krótko relację Onesikiritosa) i [[Flawiusz Arrian|Arriana]], w części także przekaz [[Plutarch]]a < ref > {{Cytuj | autor = Waldemar, Heckel, | tytuł = \'\'Who\'s who in the age of Alexander the Great. Prosopography of Alexander\'s empire\'\' | wydawca = Blackwell Publishing | data = 2006|s=46 | isbn = 978-1-4051-1210-9 | język = en}} < /ref > < ref > {{Cytuj |autor = N.G.L. Hammond |tytuł =  " Sources for Alexander the Great "  |data = 1993 |data dostępu = 2020-12-29 |isbn = 9780521432641 |wydawca = Cambridge University Press |s = 129, 279 |url = https://books.google.pl/books?id=SAym_xYgzjgC & hl=pl & source=gbs_navlinks_s |język = en}} < /ref > < ref > {{Cytuj |autor = Lionel Pearson |tytuł =  " Aristobulus the Phocian "  |czasopismo = The American Journal of Philology |data = 1952 |wolumin = 73 |numer = 1 |s = 71–75 |doi = 10.2307/292236 |jstor=292236| język = en}} < /ref > . O źródłach opowieści [[Kwintus Kurcjusz Rufus|Kwintusa Kurcjusza ...
